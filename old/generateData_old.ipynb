# %% [markdown]
# # Imports and Setting Defenitions

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import cv2

# %%
N_FREQ_CHANNELS = 512
N_TIME_SAMPLES = 1000
NOISE_STRENGTH = 1 # Noise will be in range [0, NOISE_STRENGTH)
FRB_STRENGTH = 2 # FRB intensities Will be in range [0, FRB_STRENGTH)

# Coefficients and constants in f(x)=a(x-z)**2+c
a = np.random.random()/100
c = -np.random.random()*50
z = np.random.random()*(N_TIME_SAMPLES-50)+50

# Upper and lower cut off of the parabola
upper_bound = np.random.random()*(N_FREQ_CHANNELS-100)+100
lower_bound = max(np.random.random()*upper_bound-100, 0)

# For Line Detection
N_SLOPE_SAMPLES = 10

# Experimental
DISPERSE_FRB = True # Disperse FRB as a function of frequency
DISPERSION_COEF = 3*10**12 # The Dispersion Coef

# %% [markdown]
# # Create Fake Data

# %%
# Create the raw data with background noise
data = np.random.rand(N_FREQ_CHANNELS, N_TIME_SAMPLES)*NOISE_STRENGTH

# %% [markdown]
# ## Define Functions to Draw Parabola In Data (Modified Bresenham's line algorithm)

# %%
def drawParabola(data, a, c, z, ub, lb):
    # Define f(x)
    f = lambda x: a*(x-z)**2 + c

    # For every x value in the domain [0, floor(z))
    for x in range(0, int(z)):
        y = f(x) # Get the corresponding y value

        # If the y value is in bounds
        if y < upper_bound and y > lower_bound:

            # Set the point
            data[int(y)][x] = val = np.random.random()*FRB_STRENGTH
            
            x_last = x-1
            y_last = f(x_last)

            # Fill in unfilled points on the parabola within the domain above
            data = drawBack(data, a, c, z, x_last, y_last, x, y)
            
            

    return data

# %%
# Draws the parabolas point in between
def drawBack(data, a, c, z, x1, y1, x2, y2):
    # Defin |inverse of f|
    f_inv = lambda x: z + ( ( x - c ) / a )**0.5

    # Fill in all points that are interescted by f(x) around (x1, y1), (x2, y2)
    while(y1 > y2):
        diff = x2-f_inv(y1)-0.5

        val = np.random.random()*FRB_STRENGTH

        if y1 < len(data):
            if diff > 0 :
                data[int(y1)][x1] = val
            else:
                data[int(y1)][x2] = val
                
            if DISPERSE_FRB:
                data = disperse(data, x1, y1)

        y1 -= 1

    # Return the data with the filled in
    return data

# %%
def disperse(data, x, y): 
    # Get the range to disperse the current frequency
    disperse_range = np.random.rand()*DISPERSION_COEF*(y+400)**-4

    # Do the actuall dispersion
    for i in range(-int(disperse_range/2), int(disperse_range/2)):
        if x+i >= 0 and x+i < len(data):
            data[int(y)][int(x+i)] = np.random.random()*FRB_STRENGTH
    
    return data

# %%
data = drawParabola(data, a, c, z, upper_bound, lower_bound)

# %% [markdown]
# # Display the data

# %%
plt.imshow(data, origin="lower", interpolation='nearest', aspect='auto')
plt.show()

# %%
# Can be made more efficient
def regrid(data):
    coef = 511/N_FREQ_CHANNELS**0.5
    regrided_data = np.zeros((N_FREQ_CHANNELS, N_TIME_SAMPLES))
    new_y = lambda y: coef*y**0.5
    for x in range(len(data[0])):
        y_original = np.linspace(0, N_FREQ_CHANNELS, N_FREQ_CHANNELS)
        x_data = data[:, x]
        y_data = np.array([new_y(i) for i in y_original])
        y_data_new = np.interp(y_original, y_data, x_data)

        regrided_data[:, x] = y_data_new

    return regrided_data

# %%
regrided = regrid(data)
plt.imshow(regrided, origin="lower", interpolation='nearest', aspect='auto')
plt.show()

# %%
def lineDetection(data):

# %%
print(lineDetection(regrided))
# Out:
# 57.289961630759876 1
# 0.476348052153476 -57.289961630759876 1
# 0.4588929872252585 -57.289961630759876 1
# 0.44143792229704104 -57.289961630759876 1
# 0.4239828573688236 -57.289961630759876 1
# 0.4065277924406061 -57.289961630759876 1
# 0.38907272751238864 -57.289961630759876 1
# 0.37161766258417117 -57.289961630759876 1
# 0.3541625976559537 -57.289961630759876 1
# 0.33670753272773624 -57.289961630759876 1
# 0.31925246779951877 -57.289961630759876 1
# 0.3017974028713013 -57.289961630759876 1
# 0.28434233794308383 -57.289961630759876 1
# 0.26688727301486637 -57.289961630759876 1
# 0.24943220808664893 -57.289961630759876 1
# 0.2319771431584315 -57.289961630759876 1
# 0.21452207823021405 -57.289961630759876 1
# 0.1970670133019966 -57.289961630759876 1
# 0.17961194837377917 -57.289961630759876 1
# 0.16215688344556173 -57.289961630759876 1
# 0.1447018185173443 -57.289961630759876 1
# 0.12724675358912685 -57.289961630759876 1
# 0.10979168866090941 -57.289961630759876 1
# 0.09233662373269197 -57.289961630759876 1
# 0.07488155880447453 -57.289961630759876 1
# 0.05742649387625708 -57.289961630759876 1
# 0.039971428948039636 -57.289961630759876 1
# 0.02251636401982219 -57.289961630759876 1
# 0.005061299091604743 -57.289961630759876 1
# -0.012393765836612704 -57.289961630759876 1
# -0.02984883076483015 -57.289961630759876 1
# -0.0473038956930476 -57.289961630759876 1
# -0.06475896062126504 -57.289961630759876 1
# -0.08221402554948248 -57.289961630759876 1
# -0.09966909047769992 -57.289961630759876 1
# -0.11712415540591736 -57.289961630759876 1
# -0.1345792203341348 -57.289961630759876 1
# -0.15203428526235224 -57.289961630759876 1
# -0.16948935019056968 -57.289961630759876 1
# -0.18694441511878712 -57.289961630759876 1
# -0.20439948004700456 -57.289961630759876 1
# -0.221854544975222 -57.289961630759876 1
# -0.23930960990343944 -57.289961630759876 1
# -0.2567646748316569 -57.289961630759876 1
# -0.27421973975987435 -57.289961630759876 1
# -0.2916748046880918 -57.289961630759876 1
# -0.3091298696163093 -57.289961630759876 1
# -0.32658493454452675 -57.289961630759876 1
# -0.3440399994727442 -57.289961630759876 1
# -0.3614950644009617 -57.289961630759876 1
# -0.37895012932917915 -57.289961630759876 1
# -0.3964051942573966 -57.289961630759876 1
# -0.4138602591856141 -57.289961630759876 1
# -0.43131532411383156 -57.289961630759876 1
# -0.448770389042049 -57.289961630759876 1
# -0.4662254539702665 -57.289961630759876 1
# -0.48368051889848396 -57.289961630759876 1
# -0.5011355838267014 -57.289961630759876 1
# -0.5185906487549189 -57.289961630759876 1
# -0.5360457136831364 -57.289961630759876 1
# -0.5535007786113538 -57.289961630759876 1
# -0.5709558435395713 -57.289961630759876 1
# -0.5884109084677888 -57.289961630759876 1
# -0.6058659733960062 -57.289961630759876 1
# -0.6233210383242237 -57.289961630759876 1
# -0.6407761032524412 -57.289961630759876 1
# -0.6582311681806586 -57.289961630759876 1
# -0.6756862331088761 -57.289961630759876 1
# -0.6931412980370936 -57.289961630759876 1
# -0.710596362965311 -57.289961630759876 1
# -0.7280514278935285 -57.289961630759876 1
# -0.745506492821746 -57.289961630759876 1
# -0.7629615577499634 -57.289961630759876 1
# -0.7804166226781809 -57.289961630759876 1
# -0.7978716876063984 -57.289961630759876 1
# -0.8153267525346158 -57.289961630759876 1
# -0.8327818174628333 -57.289961630759876 1
# -0.8502368823910508 -57.289961630759876 1
# -0.8676919473192682 -57.289961630759876 1
# -0.8851470122474857 -57.289961630759876 1
# -0.9026020771757032 -57.289961630759876 1
# -0.9200571421039206 -57.289961630759876 1
# -0.9375122070321381 -57.289961630759876 1
# -0.9549672719603556 -57.289961630759876 1
# -0.972422336888573 -57.289961630759876 1
# -0.9898774018167905 -57.289961630759876 1
# -1.0073324667450079 -57.289961630759876 1
# -1.0247875316732253 -57.289961630759876 1
# -1.0422425966014428 -57.289961630759876 1
# -1.0596976615296603 -57.289961630759876 1
# -1.0771527264578777 -57.289961630759876 1
# -1.0946077913860952 -57.289961630759876 1
# -1.1120628563143127 -57.289961630759876 1
# -1.1295179212425301 -57.289961630759876 1
# -1.1469729861707476 -57.289961630759876 1
# -1.164428051098965 -57.289961630759876 1
# -1.1818831160271825 -57.289961630759876 1
# -1.1993381809554 -57.289961630759876 1
# -1.2167932458836175 -57.289961630759876 1
# -1.234248310811835 -57.289961630759876 1
# -1.2517033757400524 -57.289961630759876 1
# -1.2691584406682699 -57.289961630759876 1
# -1.2866135055964874 -57.289961630759876 1
# -1.3040685705247048 -57.289961630759876 1
# -1.3215236354529223 -57.289961630759876 1
# -1.3389787003811398 -57.289961630759876 1
# -1.3564337653093572 -57.289961630759876 1
# -1.3738888302375747 -57.289961630759876 1
# -1.3913438951657922 -57.289961630759876 1
# -1.4087989600940096 -57.289961630759876 1
# -1.426254025022227 -57.289961630759876 1
# -1.4437090899504446 -57.289961630759876 1
# -1.461164154878662 -57.289961630759876 1
# -1.4786192198068795 -57.289961630759876 1
# -1.496074284735097 -57.289961630759876 1
# -1.5135293496633144 -57.289961630759876 1
# -1.530984414591532 -57.289961630759876 1
# -1.5484394795197494 -57.289961630759876 1
# -1.5658945444479668 -57.289961630759876 1
# -1.5833496093761843 -57.289961630759876 1
# -1.6008046743044018 -57.289961630759876 1
# -1.6182597392326192 -57.289961630759876 1
# -1.6357148041608367 -57.289961630759876 1
# -1.6531698690890542 -57.289961630759876 1
# -1.6706249340172716 -57.289961630759876 1
# -1.688079998945489 -57.289961630759876 1
# -1.7055350638737066 -57.289961630759876 1
# -1.722990128801924 -57.289961630759876 1
# -1.7404451937301415 -57.289961630759876 1
# -1.757900258658359 -57.289961630759876 1
# -1.7753553235865764 -57.289961630759876 1
# -1.792810388514794 -57.289961630759876 1
# -1.8102654534430114 -57.289961630759876 1
# -1.8277205183712288 -57.289961630759876 1
# -1.8451755832994463 -57.289961630759876 1
# -1.8626306482276638 -57.289961630759876 1
# -1.8800857131558812 -57.289961630759876 1
# -1.8975407780840987 -57.289961630759876 1
# -1.9149958430123162 -57.289961630759876 1
# -1.9324509079405336 -57.289961630759876 1
# -1.9499059728687511 -57.289961630759876 1
# -1.9673610377969686 -57.289961630759876 1
# -1.984816102725186 -57.289961630759876 1
# -2.0022711676534035 -57.289961630759876 1
# -2.019726232581621 -57.289961630759876 1
# -2.0371812975098385 -57.289961630759876 1
# -2.054636362438056 -57.289961630759876 1
# -2.0720914273662734 -57.289961630759876 1
# -2.089546492294491 -57.289961630759876 1
# -2.1070015572227083 -57.289961630759876 1
# -2.124456622150926 -57.289961630759876 1
# -2.1419116870791433 -57.289961630759876 1
# -2.1593667520073607 -57.289961630759876 1
# -2.176821816935578 -57.289961630759876 1
# -2.1942768818637957 -57.289961630759876 1
# -2.211731946792013 -57.289961630759876 1
# -2.2291870117202306 -57.289961630759876 1
# -2.246642076648448 -57.289961630759876 1
# -2.2640971415766655 -57.289961630759876 1
# -2.281552206504883 -57.289961630759876 1
# -2.2990072714331005 -57.289961630759876 1
# -2.316462336361318 -57.289961630759876 1
# -2.3339174012895354 -57.289961630759876 1
# -2.351372466217753 -57.289961630759876 1
# -2.3688275311459703 -57.289961630759876 1
# -2.386282596074188 -57.289961630759876 1
# -2.4037376610024053 -57.289961630759876 1
# -2.4211927259306227 -57.289961630759876 1
# -2.43864779085884 -57.289961630759876 1
# -2.4561028557870577 -57.289961630759876 1
# -2.473557920715275 -57.289961630759876 1
# -2.4910129856434926 -57.289961630759876 1
# -2.50846805057171 -57.289961630759876 1
# -2.5259231154999275 -57.289961630759876 1
# -2.543378180428145 -57.289961630759876 1
# -2.5608332453563625 -57.289961630759876 1
# -2.57828831028458 -57.289961630759876 1
# -2.5957433752127974 -57.289961630759876 1
# -2.613198440141015 -57.289961630759876 1
# -2.6306535050692323 -57.289961630759876 1
# -2.64810856999745 -57.289961630759876 1
# -2.6655636349256673 -57.289961630759876 1
# -2.6830186998538847 -57.289961630759876 1
# -2.700473764782102 -57.289961630759876 1
# -2.7179288297103197 -57.289961630759876 1
# -2.735383894638537 -57.289961630759876 1
# -2.7528389595667546 -57.289961630759876 1
# -2.770294024494972 -57.289961630759876 1
# -2.7877490894231896 -57.289961630759876 1
# -2.805204154351407 -57.289961630759876 1
# -2.8226592192796245 -57.289961630759876 1
# -2.840114284207842 -57.289961630759876 1
# -2.8575693491360594 -57.289961630759876 1
# -2.875024414064277 -57.289961630759876 1
# -2.8924794789924944 -57.289961630759876 1
# -2.909934543920712 -57.289961630759876 1
# -2.9273896088489293 -57.289961630759876 1
# -2.9448446737771468 -57.289961630759876 1
# -2.9622997387053642 -57.289961630759876 1
# -2.9797548036335817 -57.289961630759876 1
# -2.997209868561799 -57.289961630759876 1
# -3.0146649334900166 -57.289961630759876 1
# -3.032119998418234 -57.289961630759876 1
# -3.0495750633464516 -57.289961630759876 1
# -3.067030128274669 -57.289961630759876 1
# -3.0844851932028865 -57.289961630759876 1
# -3.101940258131104 -57.289961630759876 1
# -3.1193953230593214 -57.289961630759876 1
# -3.136850387987539 -57.289961630759876 1
# -3.1543054529157564 -57.289961630759876 1
# -3.171760517843974 -57.289961630759876 1
# -3.1892155827721913 -57.289961630759876 1
# -3.2066706477004088 -57.289961630759876 1
# -3.2241257126286262 -57.289961630759876 1
# -3.2415807775568437 -57.289961630759876 1
# -3.259035842485061 -57.289961630759876 1
# -3.2764909074132786 -57.289961630759876 1
# -3.293945972341496 -57.289961630759876 1
# -3.3114010372697136 -57.289961630759876 1
# -3.328856102197931 -57.289961630759876 1
# -3.3463111671261485 -57.289961630759876 1
# -3.363766232054366 -57.289961630759876 1
# -3.3812212969825834 -57.289961630759876 1
# -3.398676361910801 -57.289961630759876 1
# -3.4161314268390184 -57.289961630759876 1
# -3.433586491767236 -57.289961630759876 1
# -3.4510415566954533 -57.289961630759876 1
# -3.468496621623671 -57.289961630759876 1
# -3.4859516865518883 -57.289961630759876 1
# -3.5034067514801057 -57.289961630759876 1
# -3.520861816408323 -57.289961630759876 1
# -3.5383168813365407 -57.289961630759876 1
# -3.555771946264758 -57.289961630759876 1
# -3.5732270111929756 -57.289961630759876 1
# -3.590682076121193 -57.289961630759876 1
# -3.6081371410494105 -57.289961630759876 1
# -3.625592205977628 -57.289961630759876 1
# -3.6430472709058455 -57.289961630759876 1
# -3.660502335834063 -57.289961630759876 1
# -3.6779574007622804 -57.289961630759876 1
# -3.695412465690498 -57.289961630759876 1
# -3.7128675306187153 -57.289961630759876 1
# -3.730322595546933 -57.289961630759876 1
# -3.7477776604751503 -57.289961630759876 1
# -3.7652327254033677 -57.289961630759876 1
# -3.782687790331585 -57.289961630759876 1
# -3.8001428552598027 -57.289961630759876 1
# -3.81759792018802 -57.289961630759876 1
# -3.8350529851162376 -57.289961630759876 1
# -3.852508050044455 -57.289961630759876 1
# -3.8699631149726725 -57.289961630759876 1
# -3.88741817990089 -57.289961630759876 1
# -3.9048732448291075 -57.289961630759876 1
# -3.922328309757325 -57.289961630759876 1
# -3.9397833746855424 -57.289961630759876 1
# -3.95723843961376 -57.289961630759876 1
# -3.9746935045419773 -57.289961630759876 1
# -3.992148569470195 -57.289961630759876 1
# -4.009603634398412 -57.289961630759876 1
# -4.02705869932663 -57.289961630759876 1
# -4.044513764254847 -57.289961630759876 1
# -4.061968829183065 -57.289961630759876 1
# -4.079423894111282 -57.289961630759876 1
# -4.0968789590395 -57.289961630759876 1
# -4.114334023967717 -57.289961630759876 1
# -4.1317890888959345 -57.289961630759876 1
# -4.149244153824152 -57.289961630759876 1
# -4.1666992187523695 -57.289961630759876 1
# -4.184154283680587 -57.289961630759876 1
# -4.201609348608804 -57.289961630759876 1
# -4.219064413537022 -57.289961630759876 1
# -4.236519478465239 -57.289961630759876 1
# -4.253974543393457 -57.289961630759876 1
# -4.271429608321674 -57.289961630759876 1
# -4.288884673249892 -57.289961630759876 1
# -4.306339738178109 -57.289961630759876 1
# -4.323794803106327 -57.289961630759876 1
# -4.341249868034544 -57.289961630759876 1
# -4.358704932962762 -57.289961630759876 1
# -4.376159997890979 -57.289961630759876 1
# -4.393615062819197 -57.289961630759876 1
# -4.411070127747414 -57.289961630759876 1
# -4.4285251926756315 -57.289961630759876 1
# -4.445980257603849 -57.289961630759876 1
# -4.463435322532066 -57.289961630759876 1
# -4.480890387460284 -57.289961630759876 1
# -4.498345452388501 -57.289961630759876 1
# -4.515800517316719 -57.289961630759876 1
# -4.533255582244936 -57.289961630759876 1
# -4.550710647173154 -57.289961630759876 1
# -4.568165712101371 -57.289961630759876 1
# -4.585620777029589 -57.289961630759876 1
# -4.603075841957806 -57.289961630759876 1
# -4.620530906886024 -57.289961630759876 1
# -4.637985971814241 -57.289961630759876 1
# -4.655441036742459 -57.289961630759876 1
# -4.672896101670676 -57.289961630759876 1
# -4.6903511665988935 -57.289961630759876 1
# -4.707806231527111 -57.289961630759876 1
# -4.725261296455328 -57.289961630759876 1
# -4.742716361383546 -57.289961630759876 1
# -4.760171426311763 -57.289961630759876 1
# -4.777626491239981 -57.289961630759876 1
# -4.795081556168198 -57.289961630759876 1
# -4.812536621096416 -57.289961630759876 1
# -4.829991686024633 -57.289961630759876 1
# -4.847446750952851 -57.289961630759876 1
# -4.864901815881068 -57.289961630759876 1
# -4.882356880809286 -57.289961630759876 1
# -4.899811945737503 -57.289961630759876 1
# -4.917267010665721 -57.289961630759876 1
# -4.934722075593938 -57.289961630759876 1
# -4.9521771405221555 -57.289961630759876 1
# -4.969632205450373 -57.289961630759876 1
# -4.9870872703785905 -57.289961630759876 1
# -5.004542335306808 -57.289961630759876 1
# -5.021997400235025 -57.289961630759876 1
# -5.039452465163243 -57.289961630759876 1
# -5.05690753009146 -57.289961630759876 1
# -5.074362595019678 -57.289961630759876 1
# -5.091817659947895 -57.289961630759876 1
# -5.109272724876113 -57.289961630759876 1
# -5.12672778980433 -57.289961630759876 1
# -5.144182854732548 -57.289961630759876 1
# -5.161637919660765 -57.289961630759876 1
# -5.179092984588983 -57.289961630759876 1
# -5.1965480495172 -57.289961630759876 1
# -5.2140031144454175 -57.289961630759876 1
# -5.231458179373635 -57.289961630759876 1
# -5.2489132443018525 -57.289961630759876 1
# -5.26636830923007 -57.289961630759876 1
# -5.283823374158287 -57.289961630759876 1
# -5.301278439086505 -57.289961630759876 1
# -5.318733504014722 -57.289961630759876 1
# -5.33618856894294 -57.289961630759876 1
# -5.353643633871157 -57.289961630759876 1
# -5.371098698799375 -57.289961630759876 1
# -5.388553763727592 -57.289961630759876 1
# -5.40600882865581 -57.289961630759876 1
# -5.423463893584027 -57.289961630759876 1
# -5.440918958512245 -57.289961630759876 1
# -5.458374023440462 -57.289961630759876 1
# -5.4758290883686795 -57.289961630759876 1
# -5.493284153296897 -57.289961630759876 1
# -5.5107392182251145 -57.289961630759876 1
# -5.528194283153332 -57.289961630759876 1
# -5.545649348081549 -57.289961630759876 1
# -5.563104413009767 -57.289961630759876 1
# -5.580559477937984 -57.289961630759876 1
# -5.598014542866202 -57.289961630759876 1
# -5.615469607794419 -57.289961630759876 1
# -5.632924672722637 -57.289961630759876 1
# -5.650379737650854 -57.289961630759876 1
# -5.667834802579072 -57.289961630759876 1
# -5.685289867507289 -57.289961630759876 1
# -5.702744932435507 -57.289961630759876 1
# -5.720199997363724 -57.289961630759876 1
# -5.7376550622919416 -57.289961630759876 1
# -5.755110127220159 -57.289961630759876 1
# -5.7725651921483765 -57.289961630759876 1
# -5.790020257076594 -57.289961630759876 1
# -5.807475322004811 -57.289961630759876 1
# -5.824930386933029 -57.289961630759876 1
# -5.842385451861246 -57.289961630759876 1
# -5.859840516789464 -57.289961630759876 1
# -5.877295581717681 -57.289961630759876 1
# -5.894750646645899 -57.289961630759876 1
# -5.912205711574116 -57.289961630759876 1
# -5.929660776502334 -57.289961630759876 1
# -5.947115841430551 -57.289961630759876 1
# -5.964570906358769 -57.289961630759876 1
# -5.982025971286986 -57.289961630759876 1
# -5.999481036215204 -57.289961630759876 1
# -6.016936101143421 -57.289961630759876 1
# -6.0343911660716385 -57.289961630759876 1
# -6.051846230999856 -57.289961630759876 1
# -6.069301295928073 -57.289961630759876 1
# -6.086756360856291 -57.289961630759876 1
# -6.104211425784508 -57.289961630759876 1
# -6.121666490712726 -57.289961630759876 1
# -6.139121555640943 -57.289961630759876 1
# -6.156576620569161 -57.289961630759876 1
# -6.174031685497378 -57.289961630759876 1
# -6.191486750425596 -57.289961630759876 1
# -6.208941815353813 -57.289961630759876 1
# -6.226396880282031 -57.289961630759876 1
# -6.243851945210248 -57.289961630759876 1
# -6.261307010138466 -57.289961630759876 1
# -6.278762075066683 -57.289961630759876 1
# -6.2962171399949005 -57.289961630759876 1
# -6.313672204923118 -57.289961630759876 1
# -6.3311272698513354 -57.289961630759876 1
# -6.348582334779553 -57.289961630759876 1
# -6.36603739970777 -57.289961630759876 1
# -6.383492464635988 -57.289961630759876 1
# -6.400947529564205 -57.289961630759876 1
# -6.418402594492423 -57.289961630759876 1
# -6.43585765942064 -57.289961630759876 1
# -6.453312724348858 -57.289961630759876 1
# -6.470767789277075 -57.289961630759876 1
# -6.488222854205293 -57.289961630759876 1
# -6.50567791913351 -57.289961630759876 1
# -6.523132984061728 -57.289961630759876 1
# -6.540588048989945 -57.289961630759876 1
# -6.5580431139181625 -57.289961630759876 1
# -6.57549817884638 -57.289961630759876 1
# -6.5929532437745975 -57.289961630759876 1
# -6.610408308702815 -57.289961630759876 1
# -6.627863373631032 -57.289961630759876 1
# -6.64531843855925 -57.289961630759876 1
# -6.662773503487467 -57.289961630759876 1
# -6.680228568415685 -57.289961630759876 1
# -6.697683633343902 -57.289961630759876 1
# -6.71513869827212 -57.289961630759876 1
# -6.732593763200337 -57.289961630759876 1
# -6.750048828128555 -57.289961630759876 1
# -6.767503893056772 -57.289961630759876 1
# -6.78495895798499 -57.289961630759876 1
# -6.802414022913207 -57.289961630759876 1
# -6.8198690878414245 -57.289961630759876 1
# -6.837324152769642 -57.289961630759876 1
# -6.8547792176978595 -57.289961630759876 1
# -6.872234282626077 -57.289961630759876 1
# -6.889689347554294 -57.289961630759876 1
# -6.907144412482512 -57.289961630759876 1
# -6.924599477410729 -57.289961630759876 1
# -6.942054542338947 -57.289961630759876 1
# -6.959509607267164 -57.289961630759876 1
# -6.976964672195382 -57.289961630759876 1
# -6.994419737123599 -57.289961630759876 1
# -7.011874802051817 -57.289961630759876 1
# -7.029329866980034 -57.289961630759876 1
# -7.046784931908252 -57.289961630759876 1
# -7.064239996836469 -57.289961630759876 1
# -7.0816950617646865 -57.289961630759876 1
# -7.099150126692904 -57.289961630759876 1
# -7.1166051916211215 -57.289961630759876 1
# -7.134060256549339 -57.289961630759876 1
# -7.151515321477556 -57.289961630759876 1
# -7.168970386405774 -57.289961630759876 1
# -7.186425451333991 -57.289961630759876 1
# -7.203880516262209 -57.289961630759876 1
# -7.221335581190426 -57.289961630759876 1
# -7.238790646118644 -57.289961630759876 1
# -7.256245711046861 -57.289961630759876 1
# -7.273700775975079 -57.289961630759876 1
# -7.291155840903296 -57.289961630759876 1
# -7.308610905831514 -57.289961630759876 1
# -7.326065970759731 -57.289961630759876 1
# -7.343521035687949 -57.289961630759876 1
# -7.360976100616166 -57.289961630759876 1
# -7.3784311655443835 -57.289961630759876 1
# -7.395886230472601 -57.289961630759876 1
# -7.413341295400818 -57.289961630759876 1
# -7.430796360329036 -57.289961630759876 1
# -7.448251425257253 -57.289961630759876 1
# -7.465706490185471 -57.289961630759876 1
# -7.483161555113688 -57.289961630759876 1
# -7.500616620041906 -57.289961630759876 1
# -7.518071684970123 -57.289961630759876 1
# -7.535526749898341 -57.289961630759876 1
# -7.552981814826558 -57.289961630759876 1
# -7.570436879754776 -57.289961630759876 1
# -7.587891944682993 -57.289961630759876 1
# -7.605347009611211 -57.289961630759876 1
# -7.622802074539428 -57.289961630759876 1
# -7.6402571394676455 -57.289961630759876 1
# -7.657712204395863 -57.289961630759876 1
# -7.67516726932408 -57.289961630759876 1
# -7.692622334252298 -57.289961630759876 1
# -7.710077399180515 -57.289961630759876 1
# -7.727532464108733 -57.289961630759876 1
# -7.74498752903695 -57.289961630759876 1
# -7.762442593965168 -57.289961630759876 1
# -7.779897658893385 -57.289961630759876 1
# -7.797352723821603 -57.289961630759876 1
# -7.81480778874982 -57.289961630759876 1
# -7.832262853678038 -57.289961630759876 1
# -7.849717918606255 -57.289961630759876 1
# -7.867172983534473 -57.289961630759876 1
# -7.88462804846269 -57.289961630759876 1
# -7.9020831133909075 -57.289961630759876 1
# -7.919538178319125 -57.289961630759876 1
# 2
# 2 -0.9999999999999999 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1827-455412a41369> in <module>
# ----> 1 print(lineDetection(regrided))
#
# <ipython-input-1825-d3ed5e2cc347> in lineDetection(data)
#       9             newSum = find_sum(data, m, x_intercept)
#      10
# ---> 11             if(newSum > M[0]):
#      12                 M = ( newSum, x_intercept, m )
#      13     return M
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
